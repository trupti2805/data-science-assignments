# %%
import pandas as pd
import numpy as np
import scipy
from scipy import stats

# %%
cutlets= pd.read_csv("C:\\Users\\Trupti Kendre\\Downloads\\Cutlets.csv")

# %%
cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
cutlets.head()
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522

# %%
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %%
alpha=0.05
cutlet1=pd.DataFrame(cutlets['Unit A'])
cutlet2=pd.DataFrame(cutlets['Unit B'])
print(cutlet1,cutlet2)
# Out:
#     Unit A
# 0   6.8090
# 1   6.4376
# 2   6.9157
# 3   7.3012
# 4   7.4488
# 5   7.3871
# 6   6.8755
# 7   7.0621
# 8   6.6840
# 9   6.8236
# 10  7.3930
# 11  7.5169
# 12  6.9246
# 13  6.9256
# 14  6.5797
# 15  6.8394
# 16  6.5970
# 17  7.2705
# 18  7.2828
# 19  7.3495
# 20  6.9438
# 21  7.1560
# 22  6.5341
# 23  7.2854
# 24  6.9952
# 25  6.8568
# 26  7.2163
# 27  6.6801
# 28  6.9431
# 29  7.0852
# 30  6.7794
# 31  7.2783
# 32  7.1561
# 33  7.3943
# 34  6.9405     Unit B
# 0   6.7703
# 1   7.5093
# 2   6.7300
# 3   6.7878
# 4   7.1522
# 5   6.8110
# 6   7.2212
# 7   6.6606
# 8   7.2402
# 9   7.0503
# 10  6.8810
# 11  7.4059
# 12  6.7652
# 13  6.0380
# 14  7.1581
# 15  7.0240
# 16  6.6672
# 17  7.4314
# 18  7.3070
# 19  6.7478
# 20  6.8889
# 21  7.4220
# 22  6.5217
# 23  7.1688
# 24  6.7594
# 25  6.9399
# 26  7.0133
# 27  6.9182
# 28  6.3346
# 29  7.5459
# 30  7.0992
# 31  7.1180
# 32  6.6965
# 33  6.5780
# 34  7.3875

# %%
stats.ttest_ind(cutlet1,cutlet2)
# Out:
# Ttest_indResult(statistic=array([0.72286887]), pvalue=array([0.47223947]))

# %%
x=pd.read_csv("C:\\Users\\Trupti Kendre\\Downloads\\LabTAT.csv")
x
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
x.mean()
# Out:
# Laboratory 1    178.361583
# Laboratory 2    178.902917
# Laboratory 3    199.913250
# Laboratory 4    163.682750
# dtype: float64

# %%
x.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]>

# %%
labtat=pd.read_csv("C:\\Users\\Trupti Kendre\\Downloads\\LabTAT.csv")

# %%
labtat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %%
Laboratory_1=labtat['Laboratory 1'].mean()
Laboratory_2=labtat['Laboratory 2'].mean()
Laboratory_3=labtat['Laboratory 3'].mean()
Laboratory_4=labtat['Laboratory 4'].mean()

print('Laboratory 1 Mean = ',Laboratory_1)
print('Laboratory 2 Mean = ',Laboratory_2)
print('Laboratory 3 Mean = ',Laboratory_3)
print('Laboratory 4 Mean = ',Laboratory_4)
# Out:
# Laboratory 1 Mean =  178.36158333333339
# Laboratory 2 Mean =  178.9029166666668
# Laboratory 3 Mean =  199.91325000000003
# Laboratory 4 Mean =  163.6827499999999

# %%
print('Laboratory_1 > Laboratory_2 = ',Laboratory_1 > Laboratory_2)
print('Laboratory_2 > Laboratory_3 = ',Laboratory_2 > Laboratory_3)
print('Laboratory_3 > Laboratory_4 = ',Laboratory_3 > Laboratory_4)
print('Laboratory_4 > Laboratory_1 = ',Laboratory_4 > Laboratory_1)
# Out:
# Laboratory_1 > Laboratory_2 =  False
# Laboratory_2 > Laboratory_3 =  False
# Laboratory_3 > Laboratory_4 =  True
# Laboratory_4 > Laboratory_1 =  False

# %%
alpha=0.05
Lab1=pd.DataFrame(labtat['Laboratory 1'])
Lab2=pd.DataFrame(labtat['Laboratory 2'])
Lab3=pd.DataFrame(labtat['Laboratory 3'])
Lab4=pd.DataFrame(labtat['Laboratory 4'])
print(Lab1,Lab1,Lab3,Lab4)
# Out:
#      Laboratory 1
# 0          185.35
# 1          170.49
# 2          192.77
# 3          177.33
# 4          193.41
# ..            ...
# 115        178.49
# 116        176.08
# 117        202.48
# 118        182.40
# 119        182.09
#
# [120 rows x 1 columns]      Laboratory 1
# 0          185.35
# 1          170.49
# 2          192.77
# 3          177.33
# 4          193.41
# ..            ...
# 115        178.49
# 116        176.08
# 117        202.48
# 118        182.40
# 119        182.09
#
# [120 rows x 1 columns]      Laboratory 3
# 0          176.70
# 1          198.45
# 2          201.23
# 3          199.61
# 4          204.63
# ..            ...
# 115        193.80
# 116        215.25
# 117        203.99
# 118        194.52
# 119        221.49
#
# [120 rows x 1 columns]      Laboratory 4
# 0          166.13
# 1          160.79
# 2          185.18
# 3          176.42
# 4          152.60
# ..            ...
# 115        172.68
# 116        177.64
# 117        170.27
# ...

# %%
stats.f_oneway(Lab1,Lab2,Lab3,Lab4)
# Out:
# F_onewayResult(statistic=array([118.70421654]), pvalue=array([2.11567089e-57]))

# %%
Control=pd.Series([50, 142, 131, 70])
Treat =pd.Series([550,351,480,350])

# %%
stats.ttest_ind(Control,Treat)
# Out:
# Ttest_indResult(statistic=-6.139294288037571, pvalue=0.0008548166684701879)

# %%
customers_order=pd.read_csv("C:\\Users\\Trupti Kendre\\Downloads\\Costomer+OrderForm.csv")
customers_order
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
customers_order.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
customers_order.tail()
# Out:
#     Phillippines   Indonesia       Malta       India
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free

# %%
customers_order.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %%
alpha=0.05
Phillippines=pd.DataFrame(customers_order['Phillippines'])
Indonesia=pd.DataFrame(customers_order['Indonesia'])
Malta=pd.DataFrame(customers_order['Malta'])
India=pd.DataFrame(customers_order['India'])
print(Phillippines,Indonesia,Malta,India)
# Out:
#     Phillippines
# 0     Error Free
# 1     Error Free
# 2     Error Free
# 3     Error Free
# 4     Error Free
# ..           ...
# 295   Error Free
# 296   Error Free
# 297   Error Free
# 298   Error Free
# 299   Error Free
#
# [300 rows x 1 columns]       Indonesia
# 0    Error Free
# 1    Error Free
# 2     Defective
# 3    Error Free
# 4    Error Free
# ..          ...
# 295  Error Free
# 296  Error Free
# 297  Error Free
# 298  Error Free
# 299   Defective
#
# [300 rows x 1 columns]           Malta
# 0     Defective
# 1    Error Free
# 2     Defective
# 3    Error Free
# 4     Defective
# ..          ...
# 295  Error Free
# 296  Error Free
# 297   Defective
# 298  Error Free
# 299   Defective
#
# [300 rows x 1 columns]           India
# 0    Error Free
# 1     Defective
# 2    Error Free
# 3    Error Free
# 4    Error Free
# ..          ...
# 295  Error Free
# 296  Error Free
# 297  Error Free
# 298  Error Free
# 299  Error Free
#
# [300 rows x 1 columns]

# %%
stats.f_oneway(Phillippines,Indonesia,Malta,India)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\TRUPTI~1\AppData\Local\Temp/ipykernel_12044/929471580.py in <module>
# ----> 1 stats.f_oneway(Phillippines,Indonesia,Malta,India)
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in f_oneway(axis, *args)
#    3604         raise TypeError(f'at least two inputs are required; got {len(args)}.')
#    3605
# -> 3606     args = [np.asarray(arg, dtype=float) for arg in args]
#    3607
#    3608     # ANOVA on N groups, each in its own array
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in <listcomp>(.0)
#    3604         raise TypeError(f'at least two inputs are required; got {len(args)}.')
#    3605
# -> 3606     args = [np.asarray(arg, dtype=float) for arg in args]
#    3607
#    3608     # ANOVA on N groups, each in its own array
#
# ...
